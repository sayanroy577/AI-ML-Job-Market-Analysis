# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanroy577/AI-ML-Job-Market-Analysis/blob/main/Panda_Practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Student Marks Analysis

# %%
dic={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv','Mittal','Archana'],
     'Marks':[98,89,99,87,90,83,99],
     'Gender':['Male','Female','Female','Male','Male','Female','Female']}
df=pd.DataFrame(dic)
print(df)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
#1.Display top 3 rows

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %%
#2.Display last 3 rows

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
#3.Find shape of dataset

# %%
df.shape
# Out:
# (7, 3)

# %%
print('Number of rows',df.shape[0])
print('Number of column',df.shape[1])
# Out:
# Number of rows 7
# Number of column 3

# %%
#4.Give info of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
#5.Check null values

# %%
df.isnull()
# Out:
#     Name  Marks  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
#6.Get overall statistics

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
#7.Find unique values from gender column.

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#8.Find number of unique values from gender column.

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
#9.Find count of unique values.

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
#10.Find number of students having marks between 90 to 100.

# %%
df['Marks']>=90
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df[df['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
df[(df['Marks']>=90) & (df['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df[(df['Marks']>=90) & (df['Marks']<=100)])
# Out:
# 4

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %%
#11.Find average,min,max marks

# %%
df['Marks'].mean()
# Out:
# np.float64(92.14285714285714)

# %%
df['Marks'].min()
# Out:
# 83

# %%
df['Marks'].max()
# Out:
# 99

# %%
#12.Apply method

# %%
def marks(x):
  return x/2

# %%
df['Marks'].apply(marks)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df['Half_marks']=df['Marks'].apply(marks)

# %%
df
# Out:
#       Name  Marks  Gender  Half_marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
#13.Find length of name

# %%
df['Name'].apply(len)
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %%
#14.Drop the column

# %%
df
# Out:
#       Name  Marks  Gender  Half_marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df.drop(['Half_marks'],axis=1)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
#15.Print name of the columns.

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'Half_marks'], dtype='object')

# %%
#16.Sort the dataframe according to marks.

# %%
df.sort_values(by=['Marks'])
# Out:
#       Name  Marks  Gender  Half_marks
# 5   Mittal     83  Female        41.5
# 3   Vedant     87    Male        43.5
# 1   Aadhya     89  Female        44.5
# 4   Parshv     90    Male        45.0
# 0  Priyang     98    Male        49.0
# 2   Krisha     99  Female        49.5
# 6  Archana     99  Female        49.5

# %%
df.sort_values(by=['Marks'],ascending=False)
# Out:
#       Name  Marks  Gender  Half_marks
# 2   Krisha     99  Female        49.5
# 6  Archana     99  Female        49.5
# 0  Priyang     98    Male        49.0
# 4   Parshv     90    Male        45.0
# 1   Aadhya     89  Female        44.5
# 3   Vedant     87    Male        43.5
# 5   Mittal     83  Female        41.5

# %%
#17.Display Name & Marks of the female stuednts.

# %%
df[df['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99
